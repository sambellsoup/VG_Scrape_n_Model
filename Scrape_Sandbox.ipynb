# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import re

# %%
titles = []
metascores = []
avg_user_scores = []
user_review_counts = []
developers = []
genres = []
players = []
ratings = []
release_dates = []
platforms = []
summaries = []

# %%
site= "https://www.metacritic.com/game/switch/divinity-original-sin-ii---definitive-edition"
hdr = {'User-Agent': 'Mozilla/5.0'}
req = Request(site,headers=hdr)
page = urlopen(req)
soup = BeautifulSoup(page)
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN" "https://www.w3.org/TR/html4/strict.dtd">
# <html xml:lang="en">
# <head>
# <title>Divinity: Original Sin II - Definitive Edition for Switch Reviews - Metacritic</title>
# ...

# %%
title = soup.find('div', class_="product_title")
title
# Out:
# <div class="product_title">
# <a class="hover_none" href="/game/switch/divinity-original-sin-ii---definitive-edition">
# <h1>Divinity: Original Sin II - Definitive Edition</h1>
# </a>
# <span class="platform">
# <a href="/game/switch">
#                                                         Switch
#                                                     </a>
# </span>
# </div>

# %%
title = str(soup.find('h1'))
title = title[4:-5]

# %%
titles.append(title)

# %%
metascore = str(soup.find('div', class_='metascore_w'))
metascore[-15:-13]
# Out:
# '93'

# %%
metascore = soup.find('div', class_='metascore_w')
metascore
# Out:
# <div class="metascore_w xlarge game positive"><meta content="100" itemprop="bestRating"/><span itemprop="ratingValue">93</span></div>

# %%
metascore = metascore.find('span')
metascore
# Out:
# <span itemprop="ratingValue">93</span>

# %%
metascore
# Out:
# <span itemprop="ratingValue">93</span>

# %%
metascore = re.findall("\d\d?\d?",str(metascore))

# %%
metascore = metascore.find('span')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-135-7ae8b7bc43a9> in <module>
# ----> 1 metascore = metascore.find('span')
#
# ~/anaconda3/lib/python3.7/site-packages/bs4/element.py in __getattr__(self, key)
#    1618     def __getattr__(self, key):
#    1619         raise AttributeError(
# -> 1620             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1621         )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
metascore = str(metascore)

# %%
metascore
# Out:
# '[]'

# %%
metascore = re.search('\d', metascore)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-9bf85b4092b8> in <module>
# ----> 1 metascore = re.search('\d', metascore)
#
# ~/anaconda3/lib/python3.7/re.py in search(pattern, string, flags)
#     181     """Scan through string looking for a match to the pattern, returning
#     182     a Match object, or None if no match was found."""
# --> 183     return _compile(pattern, flags).search(string)
#     184
#     185 def sub(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
metascore
# Out:
# <re.Match object; span=(29, 30), match='9'>

# %%
x = re.search("^The.*Spain$", txt)

# %%
avguserscore = str(soup.find('div', class_='metascore_w user'))

# %%
avguserscore
# Out:
# 'None'

# %%
avguserscore = soup.find('div', class_='userscore_wrap')

# %%
avguserscore = avguserscore.find('a')

# %%
avguserscore = avguserscore.find('div')

# %%
avguserscore = str(avguserscore)

# %%
avguserscore[]
# Out:
# '<div class="metascore_w user large game positive">8.4</div>'
